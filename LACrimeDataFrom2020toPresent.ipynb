# %% [markdown]
# ## Will train on Cleaning Data Using Dataset from Gov.com

# %% [markdown]
# # First will import the required libraries

# %%
import pandas as pd # dataframe
import numpy as nb #math
import seaborn as sb # ploting

# %% [markdown]
# # Will read the CSV
#
# Will also look at the data

# %%
data = pd.read_csv('Crime_Data_from_2020_to_Present.csv')
data.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757141 entries, 0 to 757140
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           757141 non-null  int64
#  1   Date Rptd       757141 non-null  object
#  2   DATE OCC        757141 non-null  object
#  3   TIME OCC        757141 non-null  int64
#  4   AREA            757141 non-null  int64
#  5   AREA NAME       757141 non-null  object
#  6   Rpt Dist No     757141 non-null  int64
#  7   Part 1-2        757141 non-null  int64
#  8   Crm Cd          757141 non-null  int64
#  9   Crm Cd Desc     757141 non-null  object
#  10  Mocodes         653226 non-null  object
#  11  Vict Age        757141 non-null  int64
#  12  Vict Sex        658230 non-null  object
#  13  Vict Descent    658224 non-null  object
#  14  Premis Cd       757132 non-null  float64
#  15  Premis Desc     756699 non-null  object
# ...

# %%
data.isnull().mean() # will look at what percentage of the data is empty.
# Out:
# DR_NO             0.000000
# Date Rptd         0.000000
# DATE OCC          0.000000
# TIME OCC          0.000000
# AREA              0.000000
# AREA NAME         0.000000
# Rpt Dist No       0.000000
# Part 1-2          0.000000
# Crm Cd            0.000000
# Crm Cd Desc       0.000000
# Mocodes           0.137247
# Vict Age          0.000000
# Vict Sex          0.130637
# Vict Descent      0.130645
# Premis Cd         0.000012
# Premis Desc       0.000584
# Weapon Used Cd    0.652536
# Weapon Desc       0.652536
# Status            0.000000
# Status Desc       0.000000
# Crm Cd 1          0.000013
# Crm Cd 2          0.926016
# Crm Cd 3          0.997528
# Crm Cd 4          0.999926
# LOCATION          0.000000
# Cross Street      0.839221
# LAT               0.000000
# LON               0.000000
# dtype: float64

# %%
df = data.rename(columns={'Date Rptd':'DateRptd'})
df.head()
# Out:
#        DR_NO                DateRptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# ...

# %%
DR =df.DateRptd.str.split(expand=True)
DR.head(20)
# Out:
#              0         1   2
# 0   01/08/2020  12:00:00  AM
# 1   01/02/2020  12:00:00  AM
# 2   04/14/2020  12:00:00  AM
# 3   01/01/2020  12:00:00  AM
# 4   01/01/2020  12:00:00  AM
# 5   01/02/2020  12:00:00  AM
# 6   01/02/2020  12:00:00  AM
# 7   01/04/2020  12:00:00  AM
# 8   01/04/2020  12:00:00  AM
# 9   06/19/2020  12:00:00  AM
# 10  01/04/2020  12:00:00  AM
# 11  01/05/2020  12:00:00  AM
# 12  01/05/2020  12:00:00  AM
# 13  01/07/2020  12:00:00  AM
# 14  01/08/2020  12:00:00  AM
# 15  11/26/2021  12:00:00  AM
# 16  11/29/2020  12:00:00  AM
# 17  02/22/2020  12:00:00  AM
# 18  11/22/2021  12:00:00  AM
# 19  01/14/2020  12:00:00  AM

# %%
df['DateRptd'] = DR[0].values
df.head()
# Out:
#        DR_NO    DateRptd                DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468  01/08/2020  01/08/2020 12:00:00 AM      2230     3    Southwest
# 1  190101086  01/02/2020  01/01/2020 12:00:00 AM       330     1      Central
# 2  200110444  04/14/2020  02/13/2020 12:00:00 AM      1200     1      Central
# 3  191501505  01/01/2020  01/01/2020 12:00:00 AM      1730    15  N Hollywood
# 4  191921269  01/01/2020  01/01/2020 12:00:00 AM       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# ...

# %%
DOC =df["DATE OCC"].str.split(expand=True)
DOC.head()
df["DATE OCC"] = DOC[0].values
df.head()
# Out:
#        DR_NO    DateRptd    DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468  01/08/2020  01/08/2020      2230     3    Southwest
# 1  190101086  01/02/2020  01/01/2020       330     1      Central
# 2  200110444  04/14/2020  02/13/2020      1200     1      Central
# 3  191501505  01/01/2020  01/01/2020      1730    15  N Hollywood
# 4  191921269  01/01/2020  01/01/2020       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# ...

# %%
df.isnull().mean() # will look at what percentage of the data is empty.
# Out:
# DR_NO             0.000000
# DateRptd          0.000000
# DATE OCC          0.000000
# TIME OCC          0.000000
# AREA              0.000000
# AREA NAME         0.000000
# Rpt Dist No       0.000000
# Part 1-2          0.000000
# Crm Cd            0.000000
# Crm Cd Desc       0.000000
# Mocodes           0.137247
# Vict Age          0.000000
# Vict Sex          0.130637
# Vict Descent      0.130645
# Premis Cd         0.000012
# Premis Desc       0.000584
# Weapon Used Cd    0.652536
# Weapon Desc       0.652536
# Status            0.000000
# Status Desc       0.000000
# Crm Cd 1          0.000013
# Crm Cd 2          0.926016
# Crm Cd 3          0.997528
# Crm Cd 4          0.999926
# LOCATION          0.000000
# Cross Street      0.839221
# LAT               0.000000
# LON               0.000000
# dtype: float64

# %% [markdown]
# Will be dropping Columns for MOCODES, Crm Cd 1, Crm Cd 2, Crm Cd 3, Crm Cd 4, and Cross Street. These are not believed to be necessary as they do not add any value to the analysis.

# %%
DataDrop = df

# %%
DD = DataDrop.drop(['Mocodes', 'Crm Cd 1' , 'Crm Cd 2' , 'Crm Cd 3' , 'Crm Cd 4', 'Cross Street'], axis=1)

# %%
DD.columns
# Out:
# Index(['DR_NO', 'DateRptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Vict Age',
#        'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'LOCATION',
#        'LAT', 'LON'],
#       dtype='object')

# %%
DD.isnull().mean()
# Out:
# DR_NO             0.000000
# DateRptd          0.000000
# DATE OCC          0.000000
# TIME OCC          0.000000
# AREA              0.000000
# AREA NAME         0.000000
# Rpt Dist No       0.000000
# Part 1-2          0.000000
# Crm Cd            0.000000
# Crm Cd Desc       0.000000
# Vict Age          0.000000
# Vict Sex          0.130637
# Vict Descent      0.130645
# Premis Cd         0.000012
# Premis Desc       0.000584
# Weapon Used Cd    0.652536
# Weapon Desc       0.652536
# Status            0.000000
# Status Desc       0.000000
# LOCATION          0.000000
# LAT               0.000000
# LON               0.000000
# dtype: float64

# %% [markdown]
# Will fill in the missing valies for the Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Used Cd, and Weapon Desc as null. Do not want to drop null values as data is usefull.

# %%
DFNAN = DD.fillna('NAN')

# %%
DFNAN.isnull().mean()
# Out:
# DR_NO             0.0
# DateRptd          0.0
# DATE OCC          0.0
# TIME OCC          0.0
# AREA              0.0
# AREA NAME         0.0
# Rpt Dist No       0.0
# Part 1-2          0.0
# Crm Cd            0.0
# Crm Cd Desc       0.0
# Vict Age          0.0
# Vict Sex          0.0
# Vict Descent      0.0
# Premis Cd         0.0
# Premis Desc       0.0
# Weapon Used Cd    0.0
# Weapon Desc       0.0
# Status            0.0
# Status Desc       0.0
# LOCATION          0.0
# LAT               0.0
# LON               0.0
# dtype: float64

# %%
DFNAN.head()
# Out:
#        DR_NO    DateRptd    DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468  01/08/2020  01/08/2020      2230     3    Southwest
# 1  190101086  01/02/2020  01/01/2020       330     1      Central
# 2  200110444  04/14/2020  02/13/2020      1200     1      Central
# 3  191501505  01/01/2020  01/01/2020      1730    15  N Hollywood
# 4  191921269  01/01/2020  01/01/2020       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ...  Vict Descent  \
# 0                           BATTERY - SIMPLE ASSAULT  ...             B
# 1                           BATTERY - SIMPLE ASSAULT  ...             H
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...             X
# ...

# %% [markdown]
# All empty data has been filled.

# %% [markdown]
# ## Data to be exported as a CSV file

# %%
DFNAN.to_csv('CleanCrimeDatafrom2020toPresent.CSV')
